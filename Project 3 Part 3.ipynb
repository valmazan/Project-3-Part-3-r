# %% [markdown]
# # Project 3 - Part 3 (Core)

# %% [markdown]
#     For part 3 of the project you will be practicing applying an E.T.L process on your previously saved movie data. Specifically, you will create a new MySQL database after preparing the data for a relational database. You will export your database to a .sql file in your repository using MySQL Workbench.

# %% [markdown]
# ### Specifications - Database
#
# - Your stakeholder wants you to take the data you have been cleaning and collecting in Parts 1 & 2 of the project and wants you to create a MySQL database for them.
#
# - Specifically, they want the data from the following files included in your database:
#  - Title Basics:
#    - Movie ID (tconst)
#    - Primary Title
#    - Start Year
#    - Runtime (in Minutes)
#    - Genres
#  - Title Ratings
#    - Movie ID (tconst)
#    - Average Movie Rating
#    - Number of Votes
#  - The TMDB API Results (multiple files)
#    - Movie ID
#    - Revenue
#    - Budget
#    - Certification (MPAA Rating)
#
# - You should normalize the tables as best you can before adding them to your new database.
#
#    - Note: an important exception to their request is that they would like you to keep all of the data from the TMDB API in 1 table together (even though it will not be perfectly normalized).
#    - You only need to keep the imdb_id, revenue, budget, and certification columns

# %% [markdown]
# ### Required Transformation Steps for Title Basics:
#
#  - Normalize Genre:
#
#    - Convert the single string of genres from title basics into 2 new tables.
#
#     1. title_genres: with the columns:
#        - tconst
#        - genre_id
# genres:
#
# genre_id
# genre_name
#
# Discard unnecessary information:
#
#    - For the title basics table, drop the following columns:
#     - "original_title" (we will use the primary title column instead)
#     - "isAdult" ("Adult" will show up in the genres so this is redundant information).
#     - "titleType" (every row will be a movie).
#     - "genres" and other variants of genre (genre is now represented in the 2 new tables described above.
#    - Do not include the title_akas table in your SQL database.
#     - You have already filtered out the desired movies using this table, and the remaining data is mostly nulls and not of interest to the stakeholder.

# %% [markdown]
# ### MySQL Database Requirements
#
#    - Use sqlalchemy with Pandas to execute your SQL queries inside your notebook.
#
#    - Create a new database on your MySQL server and call it "movies."
#
#    - Make sure to have the following tables in your "movies" database:
#
#      - title_basics
#      - title_ratings
#      - title_genres
#      - genres
#      - tmdb_data
#
#    - Make sure to set a Primary Key for each table that isn't a joiner table (e.g., title_genres is a joiner table).
#
#    - After creating each table, show the first 5 rows of that table using a SQL query.
#
#    - Make sure to run the "SHOW TABLES" SQL query at the end of your notebook to show that all required tables have been created.
#
# ### Deliverables
#
# Submit a link to your github repository containing the Jupyter Notebook file.

# %% [markdown]
# ---

# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats


import pymysql
pymysql.install_as_MySQLdb()

from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists

# %% [markdown]
# # Loading Data

# %%
df_basics_cleaned = pd.read_csv('Data/filtered_basic_years_filtered (1).csv.gz')
df_basics_cleaned
# Out:
#             tconst  titleType                    primaryTitle  \
# 0        tt0000001      short                      Carmencita
# 1        tt0000002      short          Le clown et ses chiens
# 2        tt0000003      short                  Pauvre Pierrot
# 3        tt0000004      short                     Un bon bock
# 4        tt0000005      short                Blacksmith Scene
# ...            ...        ...                             ...
# 2890845  tt9916754      movie  Chico Albuquerque - Revelações
# 2890846  tt9916766  tvEpisode                  Episode #10.15
# 2890847  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 2890848  tt9916856      short                        The Wind
# 2890849  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle  isAdult  startYear  endYear  \
# 0                            Carmencita        0     1894.0      NaN
# 1                Le clown et ses chiens        0     1892.0      NaN
# 2                        Pauvre Pierrot        0     1892.0      NaN
# 3                           Un bon bock        0     1892.0      NaN
# 4                      Blacksmith Scene        0     1893.0      NaN
# ...                                 ...      ...        ...      ...
# 2890845  Chico Albuquerque - Revelações        0     2013.0      NaN
# 2890846                  Episode #10.15        0     2019.0      NaN
# 2890847      Horrid Henry's Comic Caper        0     2014.0      NaN
# 2890848                        The Wind        0     2015.0      NaN
# 2890849       Horrid Henry Knows It All        0     2014.0      NaN
#
#          runtimeMinutes                       genres
# 0                     1            Documentary,Short
# 1                     5              Animation,Short
# 2                     4     Animation,Comedy,Romance
# 3                    12              Animation,Short
# 4                     1                 Comedy,Short
# ...                 ...                          ...
# 2890845              49                  Documentary
# 2890846              43  Family,Game-Show,Reality-TV
# 2890847              11   Adventure,Animation,Comedy
# 2890848              27                        Short
# 2890849              10   Adventure,Animation,Comedy
#
# [2890850 rows x 9 columns]

# %%
df_filtered_ratings = pd.read_csv('Data/filtered_ratings (1).csv.gz')
df_filtered_ratings
# Out:
#            tconst parentTconst  seasonNumber  episodeNumber
# 0       tt0041951    tt0041038           1.0            9.0
# 1       tt0043426    tt0040051           3.0           42.0
# 2       tt0044093    tt0959862           1.0            6.0
# 3       tt0044668    tt0044243           2.0           16.0
# 4       tt0045960    tt0044284           2.0            3.0
# ...           ...          ...           ...            ...
# 245112  tt9914556    tt8418084           2.0            3.0
# 245113  tt9914760    tt0949793          19.0           15.0
# 245114  tt9915128    tt9548722           1.0            2.0
# 245115  tt9916200    tt3501074           5.0           19.0
# 245116  tt9916204    tt3501074           5.0           20.0
#
# [245117 rows x 4 columns]

# %%
final_tmdb_data_2000 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
final_tmdb_data_2000
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0116748    0.0  /wr0hTHwkYIRC82MwNbhOvqrw27N.jpg
# ...         ...    ...                               ...
# 7243  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 7244  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 7245  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 7246  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 7247  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN         0.0
# ...                    ...         ...
# 7243                   NaN  50000000.0
# 7244                   NaN  50000000.0
# 7245                   NaN  50000000.0
# 7246                   NaN  50000000.0
# 7247                   NaN  50000000.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2              [{'id': 878, 'name': 'Science Fiction'}]
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ...                                                 ...
# 7243  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 7244  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 7245  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 7246  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 7247  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                               homepage        id original_language  \
# 0                                  NaN       NaN               NaN
# 1                                  NaN   62127.0                en
# 2                                  NaN  110977.0                en
# 3                                  NaN  442869.0                hi
# 4                                  NaN  579396.0                hi
# ...                                ...       ...               ...
# 7243  https://www.tomandjerrymovie.com  587807.0                en
# 7244  https://www.tomandjerrymovie.com  587807.0                en
# 7245  https://www.tomandjerrymovie.com  587807.0                en
# 7246  https://www.tomandjerrymovie.com  587807.0                en
# 7247  https://www.tomandjerrymovie.com  587807.0                en
#
#        original_title  ...      revenue  runtime  \
# 0                 NaN  ...          NaN      NaN
# 1     The Fantasticks  ...          0.0     86.0
# 2       For the Cause  ...          0.0    100.0
# 3                Gang  ...          0.0    152.0
# 4            Karobaar  ...          0.0    180.0
# ...               ...  ...          ...      ...
# 7243      Tom & Jerry  ...  136536687.0    101.0
# 7244      Tom & Jerry  ...  136536687.0    101.0
# 7245      Tom & Jerry  ...  136536687.0    101.0
# 7246      Tom & Jerry  ...  136536687.0    101.0
# 7247      Tom & Jerry  ...  136536687.0    101.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# ...                                                 ...       ...
# 7243  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 7244  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 7245  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 7246  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 7247  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                             tagline            title  video  \
# 0                                               NaN              NaN    NaN
# 1     Try to remember the first time magic happened  The Fantasticks    0.0
# 2      The ultimate showdown on a forbidden planet.    For the Cause    0.0
# 3                                               NaN             Gang    0.0
# 4                              The Business of Love         Karobaar    0.0
# ...                                             ...              ...    ...
# 7243             Best of enemies. Worst of friends.      Tom & Jerry    0.0
# 7244             Best of enemies. Worst of friends.      Tom & Jerry    0.0
# 7245             Best of enemies. Worst of friends.      Tom & Jerry    0.0
# 7246             Best of enemies. Worst of friends.      Tom & Jerry    0.0
# 7247             Best of enemies. Worst of friends.      Tom & Jerry    0.0
#
#       vote_average vote_count certification
# 0              NaN        NaN           NaN
# 1              5.5       22.0           NaN
# 2              5.1        8.0           NaN
# 3              4.0        1.0           NaN
# 4              7.0        3.0           NaN
# ...            ...        ...           ...
# 7243           6.9     2243.0           NaN
# 7244           6.9     2243.0           NaN
# 7245           6.9     2243.0           NaN
# 7246           6.9     2243.0           NaN
# 7247           6.9     2243.0           NaN
#
# [7248 rows x 26 columns]

# %%
final_tmdb_data_2001 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
final_tmdb_data_2001
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 2     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 3     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 4     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# ...         ...    ...                               ...
# 8899  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 8900  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 8901  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 8902  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 8903  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
#
#       belongs_to_collection      budget  \
# 0                       NaN         NaN
# 1                       NaN  50000000.0
# 2                       NaN  50000000.0
# 3                       NaN  50000000.0
# 4                       NaN  50000000.0
# ...                     ...         ...
# 8899                    NaN  50000000.0
# 8900                    NaN  50000000.0
# 8901                    NaN  50000000.0
# 8902                    NaN  50000000.0
# 8903                    NaN  50000000.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...                                                 ...
# 8899  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 8900  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 8901  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 8902  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 8903  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                               homepage        id original_language  \
# 0                                  NaN       NaN               NaN
# 1     https://www.tomandjerrymovie.com  587807.0                en
# 2     https://www.tomandjerrymovie.com  587807.0                en
# 3     https://www.tomandjerrymovie.com  587807.0                en
# 4     https://www.tomandjerrymovie.com  587807.0                en
# ...                                ...       ...               ...
# 8899  https://www.tomandjerrymovie.com  587807.0                en
# 8900  https://www.tomandjerrymovie.com  587807.0                en
# 8901  https://www.tomandjerrymovie.com  587807.0                en
# 8902  https://www.tomandjerrymovie.com  587807.0                en
# 8903  https://www.tomandjerrymovie.com  587807.0                en
#
#      original_title  ... release_date      revenue runtime  \
# 0               NaN  ...          NaN          NaN     NaN
# 1       Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# 2       Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# 3       Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# 4       Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# ...             ...  ...          ...          ...     ...
# 8899    Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# 8900    Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# 8901    Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# 8902    Tom & Jerry  ...   2021-02-10  136536687.0   101.0
# 8903    Tom & Jerry  ...   2021-02-10  136536687.0   101.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 8899  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 8900  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 8901  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 8902  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 8903  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                  tagline        title  video vote_average  \
# 0                                    NaN          NaN    NaN          NaN
# 1     Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# 2     Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# 3     Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# 4     Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# ...                                  ...          ...    ...          ...
# 8899  Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# 8900  Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# 8901  Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# 8902  Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
# 8903  Best of enemies. Worst of friends.  Tom & Jerry    0.0          6.9
#
#      vote_count
# 0           NaN
# 1        2243.0
# 2        2243.0
# 3        2243.0
# 4        2243.0
# ...         ...
# 8899     2243.0
# 8900     2243.0
# 8901     2243.0
# 8902     2243.0
# 8903     2243.0
#
# [8904 rows x 25 columns]

# %% [markdown]
# ### Required Transformation Steps for Title Basics:

# %%
df_basics_cleaned[:3]
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
#
#    isAdult  startYear  endYear  runtimeMinutes                    genres
# 0        0     1894.0      NaN               1         Documentary,Short
# 1        0     1892.0      NaN               5           Animation,Short
# 2        0     1892.0      NaN               4  Animation,Comedy,Romance

# %%
df_basics_cleaned['genres_split'] = df_basics_cleaned['genres'].str.split(',')
df_basics_cleaned
# Out:
#             tconst  titleType                    primaryTitle  \
# 0        tt0000001      short                      Carmencita
# 1        tt0000002      short          Le clown et ses chiens
# 2        tt0000003      short                  Pauvre Pierrot
# 3        tt0000004      short                     Un bon bock
# 4        tt0000005      short                Blacksmith Scene
# ...            ...        ...                             ...
# 2890845  tt9916754      movie  Chico Albuquerque - Revelações
# 2890846  tt9916766  tvEpisode                  Episode #10.15
# 2890847  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 2890848  tt9916856      short                        The Wind
# 2890849  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle  isAdult  startYear  endYear  \
# 0                            Carmencita        0     1894.0      NaN
# 1                Le clown et ses chiens        0     1892.0      NaN
# 2                        Pauvre Pierrot        0     1892.0      NaN
# 3                           Un bon bock        0     1892.0      NaN
# 4                      Blacksmith Scene        0     1893.0      NaN
# ...                                 ...      ...        ...      ...
# 2890845  Chico Albuquerque - Revelações        0     2013.0      NaN
# 2890846                  Episode #10.15        0     2019.0      NaN
# 2890847      Horrid Henry's Comic Caper        0     2014.0      NaN
# 2890848                        The Wind        0     2015.0      NaN
# 2890849       Horrid Henry Knows It All        0     2014.0      NaN
#
#          runtimeMinutes                       genres  \
# 0                     1            Documentary,Short
# 1                     5              Animation,Short
# 2                     4     Animation,Comedy,Romance
# 3                    12              Animation,Short
# 4                     1                 Comedy,Short
# ...                 ...                          ...
# 2890845              49                  Documentary
# 2890846              43  Family,Game-Show,Reality-TV
# 2890847              11   Adventure,Animation,Comedy
# 2890848              27                        Short
# 2890849              10   Adventure,Animation,Comedy
#
#                             genres_split
# 0                   [Documentary, Short]
# 1                     [Animation, Short]
# 2           [Animation, Comedy, Romance]
# 3                     [Animation, Short]
# 4                        [Comedy, Short]
# ...                                  ...
# 2890845                    [Documentary]
# 2890846  [Family, Game-Show, Reality-TV]
# 2890847   [Adventure, Animation, Comedy]
# 2890848                          [Short]
# 2890849   [Adventure, Animation, Comedy]
#
# [2890850 rows x 10 columns]

# %%
exploded_genres = df_basics_cleaned.explode('genres_split')
exploded_genres
# Out:
#             tconst  titleType                primaryTitle  \
# 0        tt0000001      short                  Carmencita
# 0        tt0000001      short                  Carmencita
# 1        tt0000002      short      Le clown et ses chiens
# 1        tt0000002      short      Le clown et ses chiens
# 2        tt0000003      short              Pauvre Pierrot
# ...            ...        ...                         ...
# 2890847  tt9916840  tvEpisode  Horrid Henry's Comic Caper
# 2890848  tt9916856      short                    The Wind
# 2890849  tt9916880  tvEpisode   Horrid Henry Knows It All
# 2890849  tt9916880  tvEpisode   Horrid Henry Knows It All
# 2890849  tt9916880  tvEpisode   Horrid Henry Knows It All
#
#                       originalTitle  isAdult  startYear  endYear  \
# 0                        Carmencita        0     1894.0      NaN
# 0                        Carmencita        0     1894.0      NaN
# 1            Le clown et ses chiens        0     1892.0      NaN
# 1            Le clown et ses chiens        0     1892.0      NaN
# 2                    Pauvre Pierrot        0     1892.0      NaN
# ...                             ...      ...        ...      ...
# 2890847  Horrid Henry's Comic Caper        0     2014.0      NaN
# 2890848                    The Wind        0     2015.0      NaN
# 2890849   Horrid Henry Knows It All        0     2014.0      NaN
# 2890849   Horrid Henry Knows It All        0     2014.0      NaN
# 2890849   Horrid Henry Knows It All        0     2014.0      NaN
#
#          runtimeMinutes                      genres genres_split
# 0                     1           Documentary,Short  Documentary
# 0                     1           Documentary,Short        Short
# 1                     5             Animation,Short    Animation
# 1                     5             Animation,Short        Short
# 2                     4    Animation,Comedy,Romance    Animation
# ...                 ...                         ...          ...
# 2890847              11  Adventure,Animation,Comedy       Comedy
# 2890848              27                       Short        Short
# 2890849              10  Adventure,Animation,Comedy    Adventure
# 2890849              10  Adventure,Animation,Comedy    Animation
# 2890849              10  Adventure,Animation,Comedy       Comedy
#
# [5315476 rows x 10 columns]

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Film-Noir',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']
